# %%
import random
import time
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
def measure_times(f):
    times = []
    for iteration in range(1, 2001):
        print(iteration)
        v = [random.randint(0, 10) for _ in range(i)]
        current_times = []
        for _ in range(5):
            start = time.time_ns()
            f(v)
            current_times.append(time.time_ns() - start)
        times.append(sum(current_times)/len(current_times))
    return times

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('bmh')

n = np.linspace(1, 2000, 10)
big_o = np.ones(n.shape)

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
# Out:
# Text(0.5, 0, 'Input Size')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('bmh')

n = np.linspace(1, 2000, 100)
big_o = np.log(n)

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
# Out:
# Text(0.5, 0, 'Input Size')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('bmh')

n = np.linspace(1, 2000, 100)
big_o = n

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
# Out:
# Text(0.5, 0, 'Input Size')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('bmh')

n = np.linspace(1, 2000, 100)
big_o = n*np.log(n)

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
plt.savefig('big-o-notation.png')

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.linspace(1, 2000, 100)
big_o = np.log(n)

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
# Out:
# Text(0.5, 0, 'Input Size')

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.linspace(1, 2000, 100)
big_o = n**2

plt.plot(n,big_o)
plt.ylabel('Relative Runtime')
plt.xlabel('Input Size')
# Out:
# Text(0.5, 0, 'Input Size')
